# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calculate_mean(numbers):
    return sum(numbers)/len(numbers)

# %%
list_numbers = [10, 20, 30]
calculate_mean(list_numbers)
# Out:
# 20.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calculate_std(values):
    mean_values = calculate_mean(values)
    sum_distances_sq = 0
    for value in values:
        sum_distances_sq += ((value - mean_values)**2)
    inside_sqrt = (sum_distances_sq/len(values))
    return inside_sqrt**0.5

# %%
values = [1, 4, 5, 2, 8, 4]
print(calculate_std(values))
# Out:
# 2.23606797749979

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
example_1 = '50.5%'
def percent_to_float(percentage):
    return float(percentage[:-1])/100

# %%
percent_to_float(example_1)
# Out:
# 0.505

# %% [markdown]
# 4. Dividing column function:
#
#     Functions that get the first and second values from the string splitted by ' – '

# %%
# Code:
example_1 = '10–20'
def to_25(range_quant):
    return range_quant.split('–')[0]

# %%
to_25(example_1)
# Out:
# '10'

# %%
# Code:
example_1 = '10–20'
def to_75(range_quant):
    return range_quant.split('–')[1]

# %%
to_75(example_1)
# Out:
# '20'

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
act_ca = pd.read_csv('../data/act_2019_ca.csv')
sat_ca = pd.read_csv('../data/sat_2019_ca.csv')
sat_act_college = pd.read_csv('../data/sat_act_per_college.csv')
sat_college = pd.read_csv('../data/sat_2019_by_intended_college_major.csv')

# %%
sat_ca.head(5)
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
sat_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    2579 non-null   float64
#  1   CCode                  2579 non-null   float64
#  2   CDCode                 2579 non-null   float64
#  3   SCode                  2579 non-null   float64
#  4   RType                  2579 non-null   object
#  5   SName                  1982 non-null   object
#  6   DName                  2521 non-null   object
#  7   CName                  2579 non-null   object
#  8   Enroll12               2579 non-null   float64
#  9   NumTSTTakr12           2579 non-null   float64
#  10  NumERWBenchmark12      2304 non-null   object
#  11  PctERWBenchmark12      2304 non-null   object
#  12  NumMathBenchmark12     2304 non-null   object
#  13  PctMathBenchmark12     2304 non-null   object
# ...

# %%
sat_ca.drop(columns=['CDS', 'CDCode', 'DName','Enroll11', 'NumTSTTakr11', 'NumERWBenchmark11',
                       'PctERWBenchmark11', 'NumMathBenchmark11', 'PctMathBenchmark11', 'TotNumBothBenchmark11',
                       'PctBothBenchmark11', 'Year', 'Unnamed: 25'], inplace = True)
sat_ca['PctTakr'] = sat_ca['NumTSTTakr12']/sat_ca['Enroll12']

sat_ca.head()
# Out:
#    CCode      SCode RType                    SName        CName  Enroll12  \
# 0    6.0   630046.0     S  Colusa Alternative Home       Colusa      18.0
# 1    6.0   634758.0     S          Maxwell Sr High       Colusa      29.0
# 2   19.0  1930924.0     S      Belmont Senior High  Los Angeles     206.0
# 3   19.0  1931476.0     S  Canoga Park Senior High  Los Angeles     227.0
# 4   19.0  1931856.0     S     Whitman Continuation  Los Angeles      18.0
#
#    NumTSTTakr12 NumERWBenchmark12 PctERWBenchmark12 NumMathBenchmark12  \
# 0           0.0               NaN               NaN                NaN
# 1          10.0                 *                 *                  *
# 2         102.0                31             30.39                 14
# 3         113.0                54             47.79                 18
# 4          14.0                 *                 *                  *
#
#   PctMathBenchmark12 TotNumBothBenchmark12 PctBothBenchmark12   PctTakr
# ...

# %%
# Creating datasets SAT and ACT with reported benchmark percentages

# creating a SAT dataset with only reported percentage benchmarks
sat_reported = sat_ca[(sat_ca['PctBothBenchmark12'].notna()) & (sat_ca['PctBothBenchmark12'] != '*')]
# Transforming to numeric data the percentages of the different test categories
sat_reported['PctBothBenchmark12'] = sat_reported['PctBothBenchmark12'].astype(float)
sat_reported['PctMathBenchmark12'] = sat_reported['PctMathBenchmark12'].astype(float)
sat_reported['PctERWBenchmark12'] = sat_reported['PctERWBenchmark12'].astype(float)
sat_reported.dtypes
# Out:
# /var/folders/wn/9gkbqd6944j2c2zg298yhc3c0000gn/T/ipykernel_11979/2973682676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_reported['PctBothBenchmark12'] = sat_reported['PctBothBenchmark12'].astype(float)
# /var/folders/wn/9gkbqd6944j2c2zg298yhc3c0000gn/T/ipykernel_11979/2973682676.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_reported['PctMathBenchmark12'] = sat_reported['PctMathBenchmark12'].astype(float)
# ...

# %%
act_ca.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 0  3.366993e+13   33.0  3366993.0   129882.0     S
# 1  1.964212e+13   19.0  1964212.0  1995596.0     S
# 2  1.563776e+13   15.0  1563776.0  1530377.0     S
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
#
#                              SName                  DName        CName  \
# 0  21st Century Learning Institute       Beaumont Unified    Riverside
# 1      ABC Secondary (Alternative)            ABC Unified  Los Angeles
# 2      Abraham Lincoln Alternative  Southern Kern Unified         Kern
# 3             Abraham Lincoln High       San Jose Unified  Santa Clara
# 4      Abraham Lincoln Senior High    Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 0      18.0         0.0        NaN       NaN        NaN       NaN     NaN
# 1      58.0         0.0        NaN       NaN        NaN       NaN     NaN
# ...

# %%
act_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1953 non-null   object
#  11  AvgScrEng    1953 non-null   object
#  12  AvgScrMath   1953 non-null   object
#  13  AvgScrSci    1953 non-null   object
#  14  NumGE21      1953 non-null   object
#  15  PctGE21      1953 non-null   object
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
act_ca['RType'].value_counts()
# Out:
# S    1728
# D     522
# C      58
# X       1
# Name: RType, dtype: int64

# %%
sat_ca['RType'].value_counts()
# Out:
# S    1981
# D     539
# C      58
# X       1
# Name: RType, dtype: int64

# %% [markdown]
# # Filtering the dataset that have the information by counties
# To check if California uses one of the test more

# %%
act_counties = act_ca[act_ca['RType']=='C'].copy()
sat_counties = sat_ca[sat_ca['RType']=='C'].copy()

# %%
act_counties.head()
# Out:
#                CDS  CCode  CDCode  SCode RType SName DName        CName  \
# 1064  3.400000e+13   34.0     0.0    0.0     C   NaN   NaN   Sacramento
# 1065  3.900000e+13   39.0     0.0    0.0     C   NaN   NaN  San Joaquin
# 1066  1.500000e+13   15.0     0.0    0.0     C   NaN   NaN         Kern
# 1067  4.500000e+13   45.0     0.0    0.0     C   NaN   NaN       Shasta
# 1068  5.100000e+13   51.0     0.0    0.0     C   NaN   NaN       Sutter
#
#       Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 1064   19540.0      3065.0         21        20         21        21    1526
# 1065   11778.0      1348.0         22        21         21        21     693
# 1066   14229.0      1257.0         21        20         20        20     544
# 1067    2161.0       173.0         26        24         24        24     131
# 1068    1827.0       196.0         23        22         22        22     117
#
#      PctGE21     Year  Unnamed: 17
# ...

# %%
sat_counties.head()
# Out:
#       CCode  SCode RType SName        CName  Enroll12  NumTSTTakr12  \
# 1981    9.0    0.0     C   NaN    El Dorado    2226.0         604.0
# 1982   19.0    0.0     C   NaN  Los Angeles  114618.0       48676.0
# 1983   20.0    0.0     C   NaN       Madera    2352.0         442.0
# 1984   57.0    0.0     C   NaN         Yolo    2299.0         759.0
# 1985   15.0    0.0     C   NaN         Kern   14229.0        3793.0
#
#      NumERWBenchmark12 PctERWBenchmark12 NumMathBenchmark12  \
# 1981               547             90.56                458
# 1982             30081             61.80              19791
# 1983               277             62.67                136
# 1984               586             77.21                464
# 1985              2334             61.53               1481
#
#      PctMathBenchmark12 TotNumBothBenchmark12 PctBothBenchmark12   PctTakr
# 1981              75.83                   442              73.18  0.271339
# ...

# %%
print(f"the number of SAT takers in California is {int(sat_counties['NumTSTTakr12'].sum())}")
print(f"the number of ACT takers in California is {int(act_counties['NumTstTakr'].sum())}")
# Out:
# the number of SAT takers in California is 170411
# the number of ACT takers in California is 82668

# %%
# Creating a DataFrame with SAT test takers, counties and 'SAT'
sat_test_takers = sat_counties.groupby('CName')[['NumTSTTakr12']].sum()
sat_test_takers.columns = ['test_takers']
sat_test_takers['test']='SAT'
sat_test_takers.reset_index(drop=False)

# Creating a DataFrame with ACT test takers, counties and 'ACT'
act_test_takers = act_counties.groupby('CName')[['NumTstTakr']].sum()
act_test_takers.columns = ['test_takers']
act_test_takers['test']='ACT'
act_test_takers.reset_index(drop=False)

# Creating a dataframe with counties, ACT and SAT test takers
test_takers_df = pd.concat([act_test_takers, sat_test_takers], ignore_index=False)
test_takers_df.reset_index(drop=False, inplace=True)
test_takers_df
# Out:
#          CName  test_takers test
# 0      Alameda       3630.0  ACT
# 1       Alpine          0.0  ACT
# 2       Amador         37.0  ACT
# 3        Butte        226.0  ACT
# 4    Calaveras         31.0  ACT
# ..         ...          ...  ...
# 111     Tulare       1801.0  SAT
# 112   Tuolumne         80.0  SAT
# 113    Ventura       4534.0  SAT
# 114       Yolo        759.0  SAT
# 115       Yuba        178.0  SAT
#
# [116 rows x 3 columns]

# %%
test_takers_df.sort_values(by='test_takers').tail(20)
# Out:
#               CName  test_takers test
# 96      San Joaquin       3351.0  SAT
# 0           Alameda       3630.0  ACT
# 72             Kern       3793.0  SAT
# 67           Fresno       4070.0  SAT
# 42      Santa Clara       4228.0  ACT
# 113         Ventura       4534.0  SAT
# 32        Riverside       4767.0  ACT
# 64     Contra Costa       5412.0  SAT
# 35   San Bernardino       5418.0  ACT
# 58          Alameda       5946.0  SAT
# 91       Sacramento       6090.0  SAT
# 100     Santa Clara       6920.0  SAT
# 36        San Diego       8081.0  ACT
# 29           Orange       8501.0  ACT
# 93   San Bernardino      10544.0  SAT
# 94        San Diego      12872.0  SAT
# 90        Riverside      14070.0  SAT
# 87           Orange      16061.0  SAT
# 18      Los Angeles      20678.0  ACT
# 76      Los Angeles      48676.0  SAT

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize = (20, 20))

# Draw a nested barplot by species and sex

sns.catplot(
    data=test_takers[test_takers['test_takers']>= 2000], kind="bar",
    x="CName", y="test_takers", hue="test",
    errorbar="sd", palette="colorblind", alpha=1.0, height=6
)

plt.xlabel('Counties')
plt.ylabel('Test Takers')
plt.xticks(rotation = 90)
plt.title('Counties and their respective test takers');

# %% [markdown]
# Because the SAT is much more used, using SAT in the analysis covers more students and more data

# %% [markdown]
# ## Checking if there's a relation between students enrolled, percentage of benchmark met and percentage of test takers in schools dataset

# %%
sat_schools = sat_ca[sat_ca['RType']=='S'].copy()

# %%
sat_schools.head(5)
# Out:
#    CCode      SCode RType                    SName        CName  Enroll12  \
# 0    6.0   630046.0     S  Colusa Alternative Home       Colusa      18.0
# 1    6.0   634758.0     S          Maxwell Sr High       Colusa      29.0
# 2   19.0  1930924.0     S      Belmont Senior High  Los Angeles     206.0
# 3   19.0  1931476.0     S  Canoga Park Senior High  Los Angeles     227.0
# 4   19.0  1931856.0     S     Whitman Continuation  Los Angeles      18.0
#
#    NumTSTTakr12 NumERWBenchmark12 PctERWBenchmark12 NumMathBenchmark12  \
# 0           0.0               NaN               NaN                NaN
# 1          10.0                 *                 *                  *
# 2         102.0                31             30.39                 14
# 3         113.0                54             47.79                 18
# 4          14.0                 *                 *                  *
#
#   PctMathBenchmark12 TotNumBothBenchmark12 PctBothBenchmark12   PctTakr
# ...

# %%
sat_schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1981 entries, 0 to 1980
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CCode                  1981 non-null   float64
#  1   SCode                  1981 non-null   float64
#  2   RType                  1981 non-null   object
#  3   SName                  1981 non-null   object
#  4   CName                  1981 non-null   object
#  5   Enroll12               1981 non-null   float64
#  6   NumTSTTakr12           1981 non-null   float64
#  7   NumERWBenchmark12      1745 non-null   object
#  8   PctERWBenchmark12      1745 non-null   object
#  9   NumMathBenchmark12     1745 non-null   object
#  10  PctMathBenchmark12     1745 non-null   object
#  11  TotNumBothBenchmark12  1745 non-null   object
#  12  PctBothBenchmark12     1745 non-null   object
#  13  PctTakr                1961 non-null   float64
# dtypes: float64(5), object(9)
# ...

# %%
sns.scatterplot(data= sat_schools, x='Enroll12', y='PctBothBenchmark12')
plt.yticks('')
# Out:
# ([<matplotlib.axis.YTick at 0x2b93f9ab0>], [Text(0, 1002.0, '')])

# %%
sns.scatterplot(data= sat_schools, x='PctTakr', y='PctBothBenchmark12')
plt.yticks('')
# Out:
# ([<matplotlib.axis.YTick at 0x2bbb5beb0>], [Text(0, 1002.0, '')])

# %%
test_takers = test_takers.sort_values(by='test_takers').copy()
test_takers
# Out:
#            CName  test_takers test
# 1         Alpine          0.0  ACT
# 59        Alpine          0.0  SAT
# 45        Sierra          3.0  ACT
# 103       Sierra          5.0  SAT
# 7      Del Norte          5.0  ACT
# ..           ...          ...  ...
# 94     San Diego      12872.0  SAT
# 90     Riverside      14070.0  SAT
# 87        Orange      16061.0  SAT
# 18   Los Angeles      20678.0  ACT
# 76   Los Angeles      48676.0  SAT
#
# [116 rows x 3 columns]

# %% [markdown]
# ## Counties sorted by SAT percent of benchmark met or exceeded

# %%
sat_counties.dtypes
# Out:
# CCode                    float64
# SCode                    float64
# RType                     object
# SName                     object
# CName                     object
# Enroll12                 float64
# NumTSTTakr12             float64
# NumERWBenchmark12         object
# PctERWBenchmark12         object
# NumMathBenchmark12        object
# PctMathBenchmark12        object
# TotNumBothBenchmark12     object
# PctBothBenchmark12        object
# PctTakr                  float64
# dtype: object

# %%
# Transforming to numeric data the percentages of the different test categories

# %%
# filtering the sat dataset to reported benchmark pergentages
sat_reported_counties = sat_counties[(sat_counties['PctBothBenchmark12'].notna()) & (sat_counties['PctBothBenchmark12'] != '*')]

# Transforming to numeric data the percentages of the different test categories
sat_reported_counties['PctBothBenchmark12'] = sat_reported['PctBothBenchmark12'].astype(float)
sat_reported_counties['PctMathBenchmark12'] = sat_reported['PctMathBenchmark12'].astype(float)
sat_reported_counties['PctERWBenchmark12'] = sat_reported['PctERWBenchmark12'].astype(float)
sat_reported_counties.dtypes
# Out:
# /var/folders/wn/9gkbqd6944j2c2zg298yhc3c0000gn/T/ipykernel_11979/2084524527.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_reported_counties['PctBothBenchmark12'] = sat_reported['PctBothBenchmark12'].astype(float)
# /var/folders/wn/9gkbqd6944j2c2zg298yhc3c0000gn/T/ipykernel_11979/2084524527.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_reported_counties['PctMathBenchmark12'] = sat_reported['PctMathBenchmark12'].astype(float)
# ...

# %%
sat_reported_counties['Enroll12'].sum()
# Out:
# 489473.0

# %%
sat_reported_counties.shape[0]
# Out:
# 55

# %%
sat_reported_counties.sort_values('PctBothBenchmark12')['Enroll12'].sum()
# Out:
# 489473.0

# %%
sat_reported_counties.sort_values('PctBothBenchmark12')[:18]['Enroll12'].sum()
# Out:
# 246238.0

# %%
sat_reported_counties.sort_values('PctBothBenchmark12')[:18]['Enroll12'].sum()/sat_reported_counties.sort_values('PctBothBenchmark12')['Enroll12'].sum()
# Out:
# 0.5030675849331833

# %%
sat_reported_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 1981 to 2578
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CCode                  55 non-null     float64
#  1   SCode                  55 non-null     float64
#  2   RType                  55 non-null     object
#  3   SName                  0 non-null      object
#  4   CName                  55 non-null     object
#  5   Enroll12               55 non-null     float64
#  6   NumTSTTakr12           55 non-null     float64
#  7   NumERWBenchmark12      55 non-null     object
#  8   PctERWBenchmark12      55 non-null     object
#  9   NumMathBenchmark12     55 non-null     object
#  10  PctMathBenchmark12     55 non-null     object
#  11  TotNumBothBenchmark12  55 non-null     object
#  12  PctBothBenchmark12     55 non-null     float64
#  13  PctTakr                55 non-null     float64
# dtypes: float64(6), object(8)
# ...

# %%
sns.scatterplot(data=sat_reported_counties, x='PctMathBenchmark12', y='PctERWBenchmark12')
# Out:
# <Axes: xlabel='PctMathBenchmark12', ylabel='PctERWBenchmark12'>

# %%
worst_20_math = sat_reported_counties.sort_values('PctBothBenchmark12')[:20]
worst_20_math

# %%
worst_20_both = sat_reported_counties.sort_values('PctBothBenchmark12')[:20]
worst_20_both
# Out:
#       CCode  SCode RType SName           CName  Enroll12  NumTSTTakr12  \
# 2027    6.0    0.0     C   NaN          Colusa     339.0          74.0
# 2001   11.0    0.0     C   NaN           Glenn     500.0          90.0
# 1983   20.0    0.0     C   NaN          Madera    2352.0         442.0
# 2014   24.0    0.0     C   NaN          Merced    4559.0        1195.0
# 2028   14.0    0.0     C   NaN            Inyo     548.0          88.0
# 2008   27.0    0.0     C   NaN        Monterey    5768.0        1872.0
# 2003   54.0    0.0     C   NaN          Tulare    7558.0        1801.0
# 2033   16.0    0.0     C   NaN           Kings    2004.0         443.0
# 2035   33.0    0.0     C   NaN       Riverside   34277.0       14070.0
# 2020   18.0    0.0     C   NaN          Lassen     283.0          61.0
# 1985   15.0    0.0     C   NaN            Kern   14229.0        3793.0
# 2005   10.0    0.0     C   NaN          Fresno   14299.0        4070.0
# ...

# %%
worst_20_both.sort_values('Enroll12', ascending=False)
# Out:
#       CCode  SCode RType SName           CName  Enroll12  NumTSTTakr12  \
# 1982   19.0    0.0     C   NaN     Los Angeles  114618.0       48676.0
# 2035   33.0    0.0     C   NaN       Riverside   34277.0       14070.0
# 1990   36.0    0.0     C   NaN  San Bernardino   31635.0       10544.0
# 2005   10.0    0.0     C   NaN          Fresno   14299.0        4070.0
# 1985   15.0    0.0     C   NaN            Kern   14229.0        3793.0
# 2002   39.0    0.0     C   NaN     San Joaquin   11778.0        3351.0
# 2032   56.0    0.0     C   NaN         Ventura   10750.0        4534.0
# 2009   50.0    0.0     C   NaN      Stanislaus    9071.0        2373.0
# 2003   54.0    0.0     C   NaN          Tulare    7558.0        1801.0
# 2008   27.0    0.0     C   NaN        Monterey    5768.0        1872.0
# 2014   24.0    0.0     C   NaN          Merced    4559.0        1195.0
# 2024   13.0    0.0     C   NaN        Imperial    3168.0         775.0
# ...

# %%
sat_schools.sort_values('PctBothBenchmark12')['Enroll12'].sum()
# Out:
# 460926.0

# %%
sat_schools.sort_values('PctBothBenchmark12')[:400]['Enroll12'].sum()
# Out:
# 25927.0

# %%
sat_schools.sort_values('PctBothBenchmark12')[:400]['Enroll12'].sum()/sat_schools.sort_values('PctBothBenchmark12')['Enroll12'].sum()
# Out:
# 0.0562498101647553

# %%
sat_schools.shape[0]
# Out:
# 1981

# %%
sat_ca['RType'].value_counts()
# Out:
# S    1981
# D     539
# C      58
# X       1
# Name: RType, dtype: int64

# %%
worst_20

# %%
act_counties.head(5)
# Out:
#                CDS  CCode  CDCode  SCode RType SName DName        CName  \
# 1064  3.400000e+13   34.0     0.0    0.0     C   NaN   NaN   Sacramento
# 1065  3.900000e+13   39.0     0.0    0.0     C   NaN   NaN  San Joaquin
# 1066  1.500000e+13   15.0     0.0    0.0     C   NaN   NaN         Kern
# 1067  4.500000e+13   45.0     0.0    0.0     C   NaN   NaN       Shasta
# 1068  5.100000e+13   51.0     0.0    0.0     C   NaN   NaN       Sutter
#
#       Enroll12  NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21  \
# 1064   19540.0      3065.0         21        20         21        21    1526
# 1065   11778.0      1348.0         22        21         21        21     693
# 1066   14229.0      1257.0         21        20         20        20     544
# 1067    2161.0       173.0         26        24         24        24     131
# 1068    1827.0       196.0         23        22         22        22     117
#
#      PctGE21     Year  Unnamed: 17
# ...

# %%
sat_counties.head(5)
# Out:
#                CDS  CCode     CDCode  SCode RType SName DName        CName  \
# 1981  9.000000e+12    9.0   900000.0    0.0     C   NaN   NaN    El Dorado
# 1982  1.900000e+13   19.0  1900000.0    0.0     C   NaN   NaN  Los Angeles
# 1983  2.000000e+13   20.0  2000000.0    0.0     C   NaN   NaN       Madera
# 1984  5.700000e+13   57.0  5700000.0    0.0     C   NaN   NaN         Yolo
# 1985  1.500000e+13   15.0  1500000.0    0.0     C   NaN   NaN         Kern
#
#       Enroll12  NumTSTTakr12  ... NumERWBenchmark11 PctERWBenchmark11  \
# 1981    2226.0         604.0  ...               667             93.55
# 1982  114618.0       48676.0  ...             39363             57.65
# 1983    2352.0         442.0  ...               608             47.13
# 1984    2299.0         759.0  ...               709             88.85
# 1985   14229.0        3793.0  ...              2077             74.47
#
#      NumMathBenchmark11 PctMathBenchmark11  TotNumBothBenchmark12  \
# ...

# %%
sns.scatterplot(data=sat_counties, x='PctBothBenchmark12', y='Pct_Tkrs')
plt.xticks('');

# %%
sat_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 1981 to 2578
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    58 non-null     float64
#  1   CCode                  58 non-null     float64
#  2   CDCode                 58 non-null     float64
#  3   SCode                  58 non-null     float64
#  4   RType                  58 non-null     object
#  5   SName                  0 non-null      object
#  6   DName                  0 non-null      object
#  7   CName                  58 non-null     object
#  8   Enroll12               58 non-null     float64
#  9   NumTSTTakr12           58 non-null     float64
#  10  NumERWBenchmark12      57 non-null     object
#  11  PctERWBenchmark12      57 non-null     object
#  12  NumMathBenchmark12     57 non-null     object
#  13  PctMathBenchmark12     57 non-null     object
# ...

# %%
print(sat_ca['PctBothBenchmark12'].unique())
# Out:
# [nan '*' '13.73' ... '87.30' '50.28' '38.92']

# %%
sat_counties.head()
# Out:
#                CDS  CCode     CDCode  SCode RType SName DName        CName  \
# 1981  9.000000e+12    9.0   900000.0    0.0     C   NaN   NaN    El Dorado
# 1982  1.900000e+13   19.0  1900000.0    0.0     C   NaN   NaN  Los Angeles
# 1983  2.000000e+13   20.0  2000000.0    0.0     C   NaN   NaN       Madera
# 1984  5.700000e+13   57.0  5700000.0    0.0     C   NaN   NaN         Yolo
# 1985  1.500000e+13   15.0  1500000.0    0.0     C   NaN   NaN         Kern
#
#       Enroll12  NumTSTTakr12  ... PctERWBenchmark11 NumMathBenchmark11  \
# 1981    2226.0         604.0  ...             93.55                636
# 1982  114618.0       48676.0  ...             57.65              26064
# 1983    2352.0         442.0  ...             47.13                316
# 1984    2299.0         759.0  ...             88.85                605
# 1985   14229.0        3793.0  ...             74.47               1570
#
#      PctMathBenchmark11 TotNumBothBenchmark12  PctBothBenchmark12  \
# ...

# %%
sat_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 1981 to 2578
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    58 non-null     float64
#  1   CCode                  58 non-null     float64
#  2   CDCode                 58 non-null     float64
#  3   SCode                  58 non-null     float64
#  4   RType                  58 non-null     object
#  5   SName                  0 non-null      object
#  6   DName                  0 non-null      object
#  7   CName                  58 non-null     object
#  8   Enroll12               58 non-null     float64
#  9   NumTSTTakr12           58 non-null     float64
#  10  NumERWBenchmark12      57 non-null     object
#  11  PctERWBenchmark12      57 non-null     object
#  12  NumMathBenchmark12     57 non-null     object
#  13  PctMathBenchmark12     57 non-null     object
# ...

# %%
sat_reported_counties = sat_counties[(sat_counties['PctBothBenchmark12'].notna()) & (sat_counties['PctBothBenchmark12'] != '*')]

# %%
sat_reported_counties['PctBothBenchmark12'] = sat_reported['PctBothBenchmark12'].astype(float)
sat_reported_counties.head()
# Out:
# /var/folders/wn/9gkbqd6944j2c2zg298yhc3c0000gn/T/ipykernel_11979/3614409063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_reported_counties.loc['PctBothBenchmark12'] = sat_reported['PctBothBenchmark12'].astype(float)
#                CDS  CCode     CDCode  SCode RType SName DName        CName  \
# 1981  9.000000e+12    9.0   900000.0    0.0     C   NaN   NaN    El Dorado
# 1982  1.900000e+13   19.0  1900000.0    0.0     C   NaN   NaN  Los Angeles
# 1983  2.000000e+13   20.0  2000000.0    0.0     C   NaN   NaN       Madera
# 1984  5.700000e+13   57.0  5700000.0    0.0     C   NaN   NaN         Yolo
# 1985  1.500000e+13   15.0  1500000.0    0.0     C   NaN   NaN         Kern
#
#       Enroll12  NumTSTTakr12  ... PctERWBenchmark11  NumMathBenchmark11  \
# ...

# %%
sat_reported_counties['PctERWBenchmark12'] = sat_reported_counties['PctERWBenchmark12'].astype(float)
# Out:
# /var/folders/wn/9gkbqd6944j2c2zg298yhc3c0000gn/T/ipykernel_11979/1426509316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_reported_counties['PctERWBenchmark12'] = sat_reported_counties['PctERWBenchmark12'].astype(float)

# %%
sat_reported_counties['PctMathBenchmark12'] = sat_reported_counties['PctMathBenchmark12'].astype(float)
sat_reported_counties
# Out:
# /var/folders/wn/9gkbqd6944j2c2zg298yhc3c0000gn/T/ipykernel_11979/3083913939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_reported_counties['PctMathBenchmark12'] = sat_reported_counties['PctMathBenchmark12'].astype(float)
#                CDS  CCode     CDCode  SCode RType SName DName  \
# 1981  9.000000e+12    9.0   900000.0    0.0     C   NaN   NaN
# 1982  1.900000e+13   19.0  1900000.0    0.0     C   NaN   NaN
# 1983  2.000000e+13   20.0  2000000.0    0.0     C   NaN   NaN
# 1984  5.700000e+13   57.0  5700000.0    0.0     C   NaN   NaN
# 1985  1.500000e+13   15.0  1500000.0    0.0     C   NaN   NaN
# 1986  2.800000e+13   28.0  2800000.0    0.0     C   NaN   NaN
# ...

# %%
sat_reported_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 1981 to 2578
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    55 non-null     float64
#  1   CCode                  55 non-null     float64
#  2   CDCode                 55 non-null     float64
#  3   SCode                  55 non-null     float64
#  4   RType                  55 non-null     object
#  5   SName                  0 non-null      object
#  6   DName                  0 non-null      object
#  7   CName                  55 non-null     object
#  8   Enroll12               55 non-null     float64
#  9   NumTSTTakr12           55 non-null     float64
#  10  NumERWBenchmark12      55 non-null     object
#  11  PctERWBenchmark12      55 non-null     float64
#  12  NumMathBenchmark12     55 non-null     object
#  13  PctMathBenchmark12     55 non-null     float64
# ...

# %%
act_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2310 entries, 0 to 2309
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CDS          2309 non-null   float64
#  1   CCode        2309 non-null   float64
#  2   CDCode       2309 non-null   float64
#  3   SCode        1787 non-null   float64
#  4   RType        2309 non-null   object
#  5   SName        1729 non-null   object
#  6   DName        2251 non-null   object
#  7   CName        2309 non-null   object
#  8   Enroll12     2309 non-null   float64
#  9   NumTstTakr   2309 non-null   float64
#  10  AvgScrRead   1953 non-null   object
#  11  AvgScrEng    1953 non-null   object
#  12  AvgScrMath   1953 non-null   object
#  13  AvgScrSci    1953 non-null   object
#  14  NumGE21      1953 non-null   object
#  15  PctGE21      1953 non-null   object
#  16  Year         2309 non-null   object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
# Number of unique school codes
print('Number of unique schools:')
print(len(act_ca_schools['SCode'].unique()))

# Number of schools that reported scores of reading, english and math
reported_reading = (act_ca_schools['AvgScrRead'].notna()) & (act_ca_schools['AvgScrRead'].str.isdigit()) 
reported_english = (act_ca_schools['AvgScrEng'].notna()) & (act_ca_schools['AvgScrEng'].str.isdigit())
reported_math = (act_ca_schools['AvgScrMath'].notna()) & (act_ca_schools['AvgScrMath'].str.isdigit()) 
reported_english = (act_ca_schools['AvgScrSci'].notna()) & (act_ca_schools['AvgScrSci'].str.isdigit())

reported_all = act_ca_schools[reported_reading & reported_english & reported_math & reported_english]
print('Number of schools that reported ACT scores:')
print(reported_all.shape[0])

# Number of schools that have less than 14 students
print('Number of schools with less than 14 students:')
print(len(act_ca_schools[act_ca_schools['AvgScrRead']=='*']))

# Number of schools that did not report
print('Number of schools that did not report scores:')
print(len(act_ca_schools[act_ca_schools['AvgScrRead'].isna()]))

# %%
act_ca_counties = act_2019_ca[act_2019_ca['RType']=='C'].copy()

# %%
act_ca_counties.head(1)
# Out:
#             CDS  CCode     CDCode     SCode RType  \
# 0  3.366993e+13   33.0  3366993.0  129882.0     S
#
#                              SName             DName      CName  Enroll12  \
# 0  21st Century Learning Institute  Beaumont Unified  Riverside      18.0
#
#    NumTstTakr AvgScrRead AvgScrEng AvgScrMath AvgScrSci NumGE21 PctGE21  \
# 0         0.0        NaN       NaN        NaN       NaN     NaN     NaN
#
#       Year  Unnamed: 17
# 0  2018-19          NaN

# %%
act_2019_ca['RType'].value_counts()
# Out:
# S    1728
# D     522
# C      58
# X       1
# Name: RType, dtype: int64

# %%
act_ca_counties.shape[0]
# Out:
# 58

# %%
counties_average = act_ca_counties.groupby('CCode')[['AvgScrRead', 'AvgScrEng', 'AvgScrMath', 'AvgScrSci', 'CCode']].mean()

# %%
act_ca_counties = act_ca_counties.groupby('CName')[['AvgScrRead', 'AvgScrEng', 'AvgScrMath', 'AvgScrSci', 'CCode']].mean()
act_ca_counties.reset_index(inplace=True, drop=False)
act_ca_counties.head()
# Out:
#        CName  AvgScrRead  AvgScrEng  AvgScrMath  AvgScrSci  CCode
# 0    Alameda        25.0       24.0        24.0       24.0    1.0
# 1     Amador        24.0       23.0        23.0       22.0    3.0
# 2      Butte        23.0       22.0        23.0       23.0    4.0
# 3  Calaveras        26.0       24.0        24.0       24.0    5.0
# 4     Colusa        19.0       18.0        19.0       20.0    6.0

# %%
type(counties_average)

# %%
counties_average.columns

# %%
counties_average.columns = ['ACT_Read', 'ACT_Eng', 'ACT_Math', 'ACT_Sci', 'CCode']

# %%
# ACT Composite to SAT Total
act_to_sat_total = {36:1590, 35:1540, 34:1500, 33:1460, 32:1430, 31:1400, 30:1370, 29:1340, 28:1310, 27:1280,
                        26:1240, 25:1210, 24:1180, 23:1140, 22:1110, 21:1080, 20:1040, 19:1010, 18:970, 17:930,
                        16:890, 15:850, 14:800, 13:760, 12:710, 11:670, 10:630, 9:590 }

# ACT Math to SAT Math
act_to_sat_math = {36:800, 35:780, 34:760, 33:740, 32:720, 31:710, 30:700, 29:680, 28:660, 27:640,
                        26:610, 25:590, 24:580, 23:560, 22:540, 21:530, 20:520, 19:510, 18:500, 17:470,
                        16:430, 15:400, 14:360, 13:330, 12:310, 11:280, 10:260}

# ACT English + Reading to SAT ERW
act_to_sat_erw = {72: 790, 71:770, 70:750, 69:740, 68:730, 67:720, 66:710, 65:700, 64:700, 63:690, 62:680, 61:680,
                  60:670, 59:660, 58:660, 57:650, 56:640, 55:640, 54:630, 53:630, 52:620, 51:610, 50:610, 49:600,
                  48:590, 47:580, 46:580, 45:570, 44:560, 43:550, 42:540, 41:540, 40:530, 39:520, 38:510, 37:500,
                  36:500, 35:490, 34:480, 33:470, 32:460, 31:450, 30:440, 29:430, 28:420, 27:410, 26:400, 25:390,
                  24:380, 23:370, 22:360, 21:350, 20:340, 19:330, 18:320, 17:310, 16:300, 15:290, 14:280}

# %%
counties_average['ACT_EngRead'] = counties_average['ACT_Read'] + counties_average['ACT_Eng']
counties_average['ACT_Composite'] = round((counties_average['ACT_Read'] + counties_average['ACT_Eng'] + counties_average['ACT_Math'] + counties_average['ACT_Sci'])/4)

counties_average['SAT_ERW'] = counties_average['ACT_EngRead'].map(act_to_sat_erw)
counties_average['SAT_Total'] = counties_average['ACT_Composite'].map(act_to_sat_total)
counties_average['SAT_Math'] = counties_average['ACT_Math'].map(act_to_sat_math)

counties_average.head()

# %%
act_2019_ca['RType'].value_counts()

# %%
act_ca_schools = act_2019_ca[act_2019_ca['RType']=='S'].copy()
act_ca_schools.info()

# %%
act_ca_schools = reported_all.copy()
act_ca_schools.shape[0]

# %%
act_ca_schools.info()

# %%
act_ca_schools = act_ca_schools.sort_values(by = 'Enroll12', ascending = False)

# %%
act_ca_schools['AvgScrRead'].median()

# %%
act_ca_schools.dtypes

# %%
act_ca_schools['AvgScrRead'] = act_ca_schools['AvgScrRead'].astype(int)
act_ca_schools['AvgScrEng'] = act_ca_schools['AvgScrEng'].astype(int)
act_ca_schools['AvgScrMath'] = act_ca_schools['AvgScrMath'].astype(int)
act_ca_schools['AvgScrSci'] = act_ca_schools['AvgScrSci'].astype(int)
act_ca_schools.dtypes

# %%
act_ca_schools = act_ca_schools.sort_values(by = 'AvgScrRead', ascending = False)
sns.scatterplot(data = act_ca_schools , x ='Enroll12' , y = 'AvgScrRead')
#plt.a(x = , ymin= , ymax =)
plt.axhline( y = 22)
plt.title('Average Reading Score x Students enrolled in 12th grade')
plt.ylabel('Average Reading Score')
plt.xlabel('Students Enrolled in 12th Grade');

# %%
# Below reading median
read_median_filter = act_ca_schools['AvgScrRead'] < (act_ca_schools['AvgScrRead'].median())
math_median_filter = act_ca_schools['AvgScrMath'] < (act_ca_schools['AvgScrMath'].median())
eng_median_filter = act_ca_schools['AvgScrEng'] < (act_ca_schools['AvgScrEng'].median())
sci_median_filter = act_ca_schools['AvgScrSci'] < (act_ca_schools['AvgScrSci'].median())

schools_below_median = act_ca_schools[(read_median_filter) | (math_median_filter)]

# %%
schools_below_median.shape[0]

# %%
schools_below_median['Enroll12'].sum()

# %%
act_ca_schools.shape[0]

# %%
act_ca_schools['Enroll12'].sum()

# %%
schools_below_median['Enroll12'].sum()/act_ca_schools['Enroll12'].sum()

# %%
schools_below_median = schools_below_median.sort_values(by = 'AvgScrRead', ascending = False)
sns.scatterplot(data = schools_below_median , x ='Enroll12' , y = 'AvgScrRead')
#plt.a(x = , ymin= , ymax =)
plt.axhline( y = 22)
plt.title('Average Reading Score x Students enrolled in 12th grade')
plt.ylabel('Average Reading Score')
plt.xlabel('Students Enrolled in 12th Grade');

# %%
schools_below_median()

# %%
schools_below_median = schools_below_median
sns.scatterplot(data = schools_below_median , x ='Enroll12' , y = 'AvgScrMath')
#plt.a(x = , ymin= , ymax =)
plt.axhline( y = 22)
plt.title('Average Reading Score x Students enrolled in 12th grade')
plt.ylabel('Average Math Score')
plt.xlabel('Students Enrolled in 12th Grade');

# %%
act_ca_schools = act_ca_schools.sort_values(by = 'AvgScrRead', ascending = False)
sns.scatterplot(data = act_ca_schools , x ='Enroll12' , y = 'AvgScrRead')
#plt.a(x = , ymin= , ymax =)
plt.axhline( y = 22)
plt.title('Average Reading Score x Students enrolled in 12th grade')
plt.ylabel('Average Reading Score')
y_ticks = np.arange(len(set(act_ca_schools['AvgScrRead'])))
plt.yticks(y_ticks);

# %%
act_ca_schools.head()

# %%
print(act_ca_schools['Enroll12'].unique())

# %%
act_ca_400 = act_ca_schools[act_ca_schools['Enroll12'] >= 400].copy()
act_ca_400.shape[0]

# %%
len(set(act_ca_schools['CCode']))

# %%
reported_reading = (act_ca_schools['AvgScrRead'].notna()) & (act_ca_schools['AvgScrRead'].str.isdigit()) 
reported_english = (act_ca_schools['AvgScrEng'].notna()) & (act_ca_schools['AvgScrEng'].str.isdigit())
reported_math = (act_ca_schools['AvgScrMath'].notna()) & (act_ca_schools['AvgScrMath'].str.isdigit()) 
reported_english = (act_ca_schools['AvgScrSci'].notna()) & (act_ca_schools['AvgScrSci'].str.isdigit())

reported_all = act_ca_schools[reported_reading & reported_english & reported_math & reported_english]
print(len(reported_all))

# %%
len(act_ca_schools[act_ca_schools['AvgScrRead']=='*'])

# %%
len(act_ca_schools[(act_ca_schools['AvgScrRead'].notna()) & (act_ca_schools['AvgScrRead'].str.isdigit())])

# %%
len(act_ca_schools[(act_ca_schools['AvgScrRead'].isna()) | (act_ca_schools['AvgScrRead']=='*')])

# %%
712 - 420

# %%
print(len(set(act_2019_ca['CCode'])))
print(len(set(act_2019_ca['CName'])))

# %%
print(len(set(act_2019_ca['CCode'])))

# %%
print([i for i in range (14, 73)][::-1])

# %%
len(act_2019_ca[(act_2019_ca['AvgScrRead'].notna()) & (act_2019_ca['AvgScrRead'].str.isdigit())])

# %%
len(act_2019_ca[(act_2019_ca['AvgScrRead'].isna()) | (act_2019_ca['AvgScrRead']=='*')])

# %%
act_2019_ca = act_2019_ca[(act_2019_ca['AvgScrRead'].notna()) & (act_2019_ca['AvgScrRead'].str.isdigit())].copy()

# %%
sat_scores_2019_ca = act_2019_ca[['CCode', 'CName', 'Enroll12', 'AvgScrRead', 'AvgScrEng', 'AvgScrMath', 'AvgScrSci']]
sat_scores_2019_ca.columns = ['CCode', 'CName', 'Enroll12', 'ACT_Read', 'ACT_Eng', 'ACT_Math', 'ACT_Sci']
sat_scores_2019_ca.head()

# %%
sat_scores_2019_ca['ACT_EngRead'] = sat_scores_2019_ca['ACT_Read'] + sat_scores_2019_ca['ACT_Eng']
sat_scores_2019_ca['ACT_Composite'] = round((sat_scores_2019_ca['ACT_Read'] + sat_scores_2019_ca['ACT_Eng'] + sat_scores_2019_ca['ACT_Math'] + sat_scores_2019_ca['ACT_Sci'])/4)

# %%
sat_scores_2019_ca.head()

# %%
sat_scores_2019_ca.sort_values(by='Enroll12')

# %%
print(set(act_2019_ca['AvgScrRead']))

# %%
sat_act_college['Rating']=pd.Series(np.arange(sat_act_college.shape[0], 1, -1))

# %%
sat_act_college.head(1)

# %%
sat_act_college['SAT_25'] = sat_act_college['SAT Total 25th–75th Percentile'].apply(to_25)
sat_act_college['SAT_75'] = sat_act_college['SAT Total 25th–75th Percentile'].apply(to_75)
sat_act_college.head()

# %%
sat_act_college['Accept Rate'] = sat_act_college['Accept Rate'].apply(percent_to_float)
sat_act_college = sat_act_college.sort_values(by = 'Accept Rate').copy()
sat_act_college.reset_index(inplace=True, drop=True)

# %%
len(sat_act_college['School'].unique())

# %%
len(sat_act_college['Accept Rate'].unique())

# %%
act_2019_ca.head(1)

# %%
sat_2019_college.head(10)

# %%
sat_2019_college['Percent'] = sat_2019_college['Percent'].apply(percent_to_float)

# %%
sat_act_college.head()

# %%
act_2019_ca['RType'].value_counts(dropna=False)

# %%
act_2019_ca.head()

# %%
len(list(act_2019_ca['CDCode'].unique()))

# %%
len(list(act_2019_ca['CCode'].unique()))

# %%
sat_2019_college.info()

# %%
sat_2019_college.head(1)

# %%
act_2019_ca['SName'].value_counts()

# %%
sat_act_college.info()

# %%
sat_act_college.info()

# %%
sat = pd.concat([sat_2017, sat_2018, sat_2019])
sat.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#
#    Year
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017

# %%
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               155 non-null    object
#  1   Participation                       155 non-null    object
#  2   Evidence-Based Reading and Writing  155 non-null    int64
#  3   Math                                155 non-null    int64
#  4   Total                               155 non-null    int64
#  5   Year                                155 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 8.5+ KB

# %%
sat[~sat['Participation'].str.contains('%')]
# Out:
#              State Participation  Evidence-Based Reading and Writing  Math  \
# 39     Puerto Rico             —                                 483   462
# 47  Virgin Islands             —                                 490   445
#
#     Total  Year
# 39    944  2019
# 47    935  2019

# %%
sat = sat[sat['Participation'].str.contains('%')].copy()
sat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 153 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               153 non-null    object
#  1   Participation                       153 non-null    object
#  2   Evidence-Based Reading and Writing  153 non-null    int64
#  3   Math                                153 non-null    int64
#  4   Total                               153 non-null    int64
#  5   Year                                153 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 8.4+ KB

# %%
sat['Participation rate'] = sat['Participation'].apply(percent_to_float)

# %%
sat.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total  \
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#
#    Year  Participation rate
# 0  2017                0.05
# 1  2017                0.38
# 2  2017                0.30
# 3  2017                0.03
# 4  2017                0.53

# %%
sat.dtypes
# Out:
# State                                  object
# Participation                          object
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# Year                                    int64
# Participation rate                    float64
# dtype: object

# %%
# Code:
act_2017 = pd.read_csv('../data/act_2017.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')
act_2019 = pd.read_csv('../data/act_2019.csv')

# %%
act_2017['Year'] = 2017
act_2018['Year'] = 2018
act_2019['Year'] = 2019

# %%
act_2017.head()

# %%
act_2018.head()

# %%
act_2019.head()

# %%
act = pd.concat([act_2017, act_2018, act_2019])[['State', 'Participation', 'Composite', 'Year']]
# Reset Index
act.head()

# %%
act.info()

# %%
act['Participation rate'] = act['Participation'].apply(lambda x: percent_to_float(x))

# %%
act.head()

# %%
states_act = set(act.State.unique())
states_sat = set(sat.State.unique())

# %%
states_act - states_sat

# %%
states_sat - states_act

# %%
act.replace({'District of columbia': 'District of Columbia'}, inplace = True)

# %%
act.State.unique()

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Code:

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
import plotly.express as px

# %%
# create figure
fig = px.choropleth(locationmode='country names', color=[1], scope="usa")
 
fig.show()

# %%
# Code

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
